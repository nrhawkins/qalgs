# %% [markdown]
# Exercise 2: 2 Qubit Circuit
#
# Starting in state α|00⟩ + β|11⟩ create a circuit that generates a 1/2 * (β|00⟩+α|01⟩-β|10⟩+α|11⟩) state.

# %%
import qiskit
from qiskit.quantum_info import Statevector, state_fidelity
from math import sqrt
from qiskit.visualization import plot_state_qsphere

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.quantum_info import Operator

# %%
qr = QuantumRegister(2, 'q')
qc = QuantumCircuit(qr)

# %%
qc.h(qr[0])
qc.cx(qr[0],qr[1])

qc.h(qr[0])

# %%
op = Operator(qc)
op.data
# Out:
# array([[ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#          0.70710678+0.j],
#        [-0.70710678+0.j,  0.70710678+0.j,  0.        +0.j,
#          0.        +0.j],
#        [-0.70710678+0.j, -0.70710678+0.j,  0.        +0.j,
#          0.        +0.j],
#        [ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#         -0.70710678+0.j]])

# %%
sv = Statevector([1/sqrt(2), 0, 0, sqrt(1)/sqrt(2)])

# %%
sv
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
print(sv.to_dict())
# Out:
# {'00': (0.7071067811865475+0j), '11': (0.7071067811865475+0j)}

# %%
plot_state_qsphere(sv.data)

# %%
new_sv = sv.evolve(qc)
new_sv.data/0.5
# Out:
# array([ 1.+0.j, -1.+0.j, -1.+0.j, -1.+0.j])

# %%
plot_state_qsphere(new_sv.data)

# %%
sv_minus = Statevector.from_label("-")
print(sv_minus)
plot_state_qsphere(sv_minus.data)
# Out:
# Statevector([ 0.70710678+0.j, -0.70710678+0.j],
#             dims=(2,))
